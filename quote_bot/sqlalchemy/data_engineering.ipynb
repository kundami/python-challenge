# %%
import json
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import imp
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

# Create Dog and Cat Classes
# ----------------------------------

# %%
# Load in csv
df_stations = pd.read_csv("Resources/hawaii_stations.csv")
df_stations.head()
# Out:
#        station                                    name  latitude  longitude  \
# 0  USC00519397                    WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1  USC00513117                    KANEOHE 838.1, HI US   21.4234  -157.8015
# 2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US   21.5213  -157.8374
# 3  USC00517948                       PEARL CITY, HI US   21.3934  -157.9751
# 4  USC00518838              UPPER WAHIAWA 874.3, HI US   21.4992  -158.0111
#
#    elevation
# 0        3.0
# 1       14.6
# 2        7.0
# 3       11.9
# 4      306.6

# %%
# Load in csv
df_measure =  pd.read_csv("Resources/hawaii_measurements.csv")
df_measure.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
df_measure.dropna(how='any',inplace = True)

# %%
df_stations.dropna(how='any',inplace = True)

# %%
df_stations.to_csv("output/hawaii_stations_clean.csv")

# %%
df_measure.to_csv("output/hawaii_measurements_clean.csv")

# %%
# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()

# Creates Classes which will serve as the anchor points for our Tables
class Station(Base):
    __tablename__ = 'Stations'
    id = Column(Integer, primary_key=True)
    station = Column(String(100))
    name = Column(String(255))
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Float)
    
class Measurement(Base):
    __tablename__ = 'Measurement'
    id = Column(Integer, primary_key=True)
    station = Column(String(255))
    date = Column(String(255))
    prcp = Column(Float)
    tobs = Column(Integer)

# Create Database Connection
# ----------------------------------
# Creates a connection to our DB using the MySQL Connect Engine
engine = create_engine('mysql://krpgzj1i2w7kvsrc:pqntjutokjvfndbs@lgg2gx1ha7yp2w0k.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/ufa78vp7mh7q2ohz')
conn = engine.connect()

# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)
# Use the `engine` and connection string to create a database called `hawaii.sqlite`
#Heroku does not allow to

# %%
# df_stations.to_sql(con=engine, name='ufa78vp7mh7q2ohz.Stations', if_exists='append')

# %%
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
for i, row in enumerate(df_stations.values):
    stat_str, name_str, lat, lon, elev = row
    print("Now inserting station"+name_str)
    station_object = Station(station = stat_str, name=name_str, latitude = lat, longitude = lon, elevation = elev)
    session.add(station_object)
    session.commit()
# Finished Inserting stations
# Out:
# Now inserting stationWAIKIKI 717.2, HI US
# Now inserting stationKANEOHE 838.1, HI US
# Now inserting stationKUALOA RANCH HEADQUARTERS 886.9, HI US
# Now inserting stationPEARL CITY, HI US
# Now inserting stationUPPER WAHIAWA 874.3, HI US
# Now inserting stationWAIMANALO EXPERIMENTAL FARM, HI US
# Now inserting stationWAIHEE 837.5, HI US
# Now inserting stationHONOLULU OBSERVATORY 702.2, HI US
# Now inserting stationMANOA LYON ARBO 785.2, HI US

# %%
for i, row in enumerate(df_measure.values):
    stat_str, date_str, prcp, tobs = row
    print("Now inserting Measurements"+stat_str)
    measure_object = Measurement(station = stat_str, date = date_str, prcp = prcp, tobs = tobs)
    session.add(measure_object)
    session.commit()
# Out:
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# Now inserting MeasurementsUSC00519397
# ...

# %%
# ----------------------------------
# Perform a simple query of the database
station_list = session.query(Station)
print("There")
for station in station_list:
    print("Here")
    print(station.name)
# Out:
# There
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\kundami\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# C:\Users\kundami\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# C:\Users\kundami\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
# ...

# %%
# Design a query to retrieve the last 12 months of precipitation data.
