# %%
import pandas as pd

# %%
df = pd.read_csv("resources/mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit([s for l in df['class'] for s in l])
# Out:
# LabelEncoder()

# %%
df["class1"] = le.fit_transform(df['class'])

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ...   stalk-color-above-ring  \
# 0            c         n          k  ...                        w
# 1            c         b          k  ...                        w
# 2            c         b          n  ...                        w
# 3            c         n          n  ...                        w
# 4            w         b          k  ...                        w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# ...

# %%
df['class2'] = le.inverse_transform(df['class1'])
# Out:
# C:\Users\kundami\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
le.classes_
# Out:
# array(['e', 'p'], dtype=object)

# %%
#Categoricals..

# %%
df['class'] = df['class'].astype('category')
df['class'].cat.categories
cat_columns = df.select_dtypes(['category']).columnsm #Get all columns of category type
df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

# %%
df.head()
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      1         x           s         n       t    p               f
# 1      0         x           s         y       t    a               f
# 2      0         b           s         w       t    l               f
# 3      1         x           y         w       t    p               f
# 4      0         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ...   stalk-color-below-ring veil-type  \
# 0            c         n          k  ...                        w         p
# 1            c         b          k  ...                        w         p
# 2            c         b          n  ...                        w         p
# 3            c         n          n  ...                        w         p
# 4            w         b          k  ...                        w         p
#
#   veil-color ring-number ring-type spore-print-color population habitat  \
# ...

# %%
## One hot vector encoding...
from sklearn.feature_extraction import DictVectorizer

# %%
vec = DictVectorizer()

# %%
D = [{'foo': 1, 'bar': 2}, {'foo': 3, 'baz': 1}]

# %%
gill_spacing = vec.fit_transform(D)
#print(gill_spacing) 
#arr = vec.fit_transform(gill_spacing)

# %%
print(gill_spacing)
# Out:
#   (0, 0)	2.0
#   (0, 2)	1.0
#   (1, 1)	1.0
#   (1, 2)	3.0

# %%
df_vect = df.loc[:,['cap-shape','cap-surface']]

# %%
#df_vect.to_dict(orient='records')
cat_dict = df[ cols_to_retain ].to_dict( orient = 'records' )
# Out:
# [{'cap-shape': 'x', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 's'},
#  {'cap-shape': 'b', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'x', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'b', 'cap-surface': 's'},
#  {'cap-shape': 'b', 'cap-surface': 'y'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'b', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'b', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'x', 'cap-surface': 'f'},
#  {'cap-shape': 's', 'cap-surface': 'f'},
#  {'cap-shape': 'f', 'cap-surface': 'f'},
#  {'cap-shape': 'x', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'x', 'cap-surface': 's'},
#  {'cap-shape': 'b', 'cap-surface': 's'},
#  {'cap-shape': 'x', 'cap-surface': 'y'},
#  {'cap-shape': 'b', 'cap-surface': 'y'},
# ...

# %%
## trying get_dummies another way to perform one hot vector encoding..
df_one_hot =  pd.get_dummies(data=df, columns=['cap-shape','cap-surface'])

# %%
df_one_hot.head()
# Out:
#    class cap-color bruises odor gill-attachment gill-spacing gill-size  \
# 0      1         n       t    p               f            c         n
# 1      0         y       t    a               f            c         b
# 2      0         w       t    l               f            c         b
# 3      1         w       t    p               f            c         n
# 4      0         g       f    n               f            w         b
#
#   gill-color stalk-shape stalk-root      ...      cap-shape_b cap-shape_c  \
# 0          k           e          e      ...                0           0
# 1          k           e          c      ...                0           0
# 2          n           e          c      ...                1           0
# 3          n           e          e      ...                0           0
# 4          k           t          e      ...                0           0
#
#   cap-shape_f cap-shape_k cap-shape_s cap-shape_x cap-surface_f cap-surface_g  \
# ...
