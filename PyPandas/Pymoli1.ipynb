# %%
## Heros of Pymoli

#### Observed Trend 1
#### Men are 4 times more likely to be playing and purchasing Video games ( Men - 81% Women - 17%)
#### Observed Trend 2
#### As you age you trend to spend more on video games
#### Observed Trend 3
#### Top 5 most popular games are also Highest Grossing games.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("purchase_data.json")
df.columns = [ 'Age','Gender','ItemID','ItemName','Price','SN']
df
# Out:
#      Age                 Gender  ItemID  \
# 0     38                   Male     165
# 1     21                   Male     119
# 2     34                   Male     174
# 3     21                   Male      92
# 4     23                   Male      63
# 5     20                   Male      10
# 6     20                   Male     153
# 7     29                 Female     169
# 8     25                   Male     118
# 9     31                   Male      99
# 10    24                   Male      57
# 11    20                   Male      47
# 12    30                   Male      81
# 13    23                   Male      77
# 14    40                   Male      44
# 15    21                   Male      96
# 16    22                 Female     123
# 17    22                 Female      59
# 18    28                   Male      91
# 19    31                   Male     177
# 20    24                   Male      78
# 21    15                   Male       3
# ...

# %%
#Total Number of Players
NumPlayers=df['Age'].count()
print(str(NumPlayers))
# Out:
# 780

# %%
# Number of Unique Items
df['ItemName'].unique
# Average Purchase Price
# Out:
# <bound method Series.unique of 0                    Bone Crushing Silver Skewer
# 1      Stormbringer, Dark Blade of Ending Misery
# 2                                Primitive Blade
# 3                                   Final Critic
# 4                                 Stormfury Mace
# 5                                    Sleepwalker
# 6                                Mercenary Sabre
# 7         Interrogator, Blood Blade of the Queen
# 8               Ghost Reaver, Longsword of Magic
# 9           Expiration, Warscythe Of Lost Worlds
# 10               Despair, Favor of Due Diligence
# 11                   Alpha, Reach of Ending Hope
# 12                                     Dreamkiss
# 13                    Piety, Guardian of Riddles
# 14                         Bonecarvin Battle Axe
# 15                   Blood-Forged Skeletal Spine
# 16                             Twilight's Carver
# 17                 Lightning, Etcher of the King
# 18                                       Celeste
# ...

# %%
# Average Purchase Price
NumPlayers=df['Age'].count()
df['Price'].sum()/NumPlayers
# Out:
# 2.931192307692303

# %%
# Total Number of Purchases
NumPlayers=df['ItemID'].count()
print("####Player Count")
print(str(NumPlayers))
# Out:
# ####Player Count
# 780

# %%
# Total Revenue
df['Price'].sum()
# Out:
# 2286.3299999999963

# %%
# Percentage and Count of Male Players
#df.loc[df.country == 'US']['id'].count()
#df1['average_backer_us'] = df.loc[df.country == 'US']['id'].count()/df['backers_count'].
male_per=100*df.loc[df.Gender == 'Male']['SN'].count()/NumPlayers
print ( str(round(male_per,2)) )
# Out:
# 81.15

# %%
# Percentage and Count of Female Players
female_per=100*df.loc[df.Gender == 'Female']['SN'].count()/NumPlayers
print ( str(round(female_per,2)) )
# Out:
# 17.44

# %%
# Percentage and Count of Other / Non-Disclosed
#surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]
nether_per=100*df.loc[(df.Gender != 'Female') & ( df.Gender != 'Male') ]['SN'].count()/NumPlayers
print ( str(round(nether_per,2)) )
# Out:
# 1.41

# %%
# The below each broken by gender
  # Purchase Count
pcou = df.loc[df.Gender == 'Male']['SN'].count()
  # Average Purchase Price
pavg =  df.loc[df.Gender == 'Male']['Price'].mean()
  # Total Purchase Value
pval = df.loc[df.Gender == 'Male']['Price'].sum()
  # Normalized Totals
print("Purchase stats by Male---")
print ("Purchase Count:"+str(pcou)+" Avg Price:"+str(round(pavg,2))+" Sum Val:"+str(round(pval,2)) )
# Out:
# Purchase stats by Male---
# Purchase Count:633 Avg Price:2.95 Sum Val:1867.68

# %%
# The below each broken by gender
  # Purchase Count
pcou = df.loc[df.Gender == 'Female']['SN'].count()
  # Average Purchase Price
pavg =  df.loc[df.Gender == 'Female']['Price'].mean()
  # Total Purchase Value
pval = df.loc[df.Gender == 'Female']['Price'].sum()
  # Normalized Totals
print("Purchase stats by Female---")
print ("Purchase Count:"+str(pcou)+" Avg Price:"+str(round(pavg,2))+" Sum Val:"+str(round(pval,2)) )
# Out:
# Purchase stats by Female---
# Purchase Count:136 Avg Price:2.82 Sum Val:382.91

# %%
df.loc[ df.SN == 'Undirrala66']
# Out:
#      Age Gender  ItemID                    ItemName  Price           SN
# 79    29   Male     144      Blood Infused Guardian   2.86  Undirrala66
# 107   29   Male     115  Spectral Diamond Doomblade   4.25  Undirrala66
# 131   29   Male      62                 Piece Maker   4.36  Undirrala66
# 537   29   Male      18  Torchlight, Bond of Storms   1.77  Undirrala66
# 596   29   Male     133            Faith's Scimitar   3.82  Undirrala66

# %%
#**Age Demographics**

#* The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.) 
#  * Purchase Count
df_10 = df.loc[df.Age < 10]

avg_10 = df_10['Price'].sum()/df_10['Price'].count()
tot_10 = df_10['Price'].sum() 

df_14 = df.loc[ ( df.Age >= 10 ) & (df.Age <= 14) ]

avg_14 = df_14['Price'].sum()/df_14['Price'].count()
tot_14 = df_14['Price'].sum() 

df_19 = df.loc[ ( df.Age <= 15 ) & (df.Age <= 19) ]

avg_19 = df_19['Price'].sum()/df_19['Price'].count()
tot_19 = df_19['Price'].sum() 

#df_19
####Age Demographics**
#### * Average Purchase Price
#### * Total Purchase Value
#### * Normalized Totals
print("Average 10 under:"+str(round(avg_10,2))+" Sum: "+str(round(tot_10,2)) )
print("Average 14 under:"+str(round(avg_14,2))+" Sum: "+str(round(tot_14,2)) )
print("Average 19 under:"+str(round(avg_19,2))+" Sum: "+str(round(tot_19,2)) )
# Out:
# Average 10 under:2.98 Sum: 83.46
# Average 14 under:2.77 Sum: 96.95
# Average 19 under:2.92 Sum: 320.77

# %%
# Identify the the top 5 spenders in the game by total purchase value, then list (in a table):
  # SN  df.groupby('A').sum().sort('B')
  

df1 = df.groupby('SN', sort=False).sum()  
df1['Counts'] = df.groupby(['SN'])['Price'].count()
df1['Average'] = df.groupby(['SN'])['Price'].mean()
df1['Sum'] = df.groupby(['SN'])['Price'].sum()
df1.sort_values(['Price'], ascending=False, inplace=True)
df1.head(5)
# Out:
#              Age  ItemID  Price  Counts   Average    Sum
# SN
# Undirrala66  145     472  17.06       5  3.412000  17.06
# Saedue76     100     233  13.56       4  3.390000  13.56
# Mindimnya67  156     609  12.74       4  3.185000  12.74
# Haellysu29    63     353  12.73       3  4.243333  12.73
# Eoda93        66     284  11.58       3  3.860000  11.58

# %%
# Identify the 5 most popular items by purchase count, then list (in a table):
#  * Item ID
#  * Item Name
#  * Purchase Count
#  * Item Price
#  * Total Purchase Value
df2 = df.groupby('ItemName', sort=False).count() 
df2['ItemCount'] = df.groupby(['ItemName'])['Price'].count()
df2.sort_values(['ItemCount'], ascending=False, inplace=True)
df2.head(5)
# Out:
#                                       Age  Gender  ItemID  Price  SN  \
# ItemName
# Final Critic                           14      14      14     14  14
# Arcane Gem                             11      11      11     11  11
# Betrayal, Whisper of Grieving Widows   11      11      11     11  11
# Stormcaller                            10      10      10     10  10
# Woeful Adamantite Claymore              9       9       9      9   9
#
#                                       ItemCount
# ItemName
# Final Critic                                 14
# Arcane Gem                                   11
# Betrayal, Whisper of Grieving Widows         11
# Stormcaller                                  10
# Woeful Adamantite Claymore                    9

# %%
df.loc[df.ItemName=='Arcane Gem']
# Out:
#      Age  Gender  ItemID    ItemName  Price             SN
# 116   25    Male      84  Arcane Gem   2.23     Koikirra25
# 171   21    Male      84  Arcane Gem   2.23  Stryanastip77
# 297   24    Male      84  Arcane Gem   2.23     Yarolwen77
# 338   17    Male      84  Arcane Gem   2.23   Lisossanya98
# 354   20    Male      84  Arcane Gem   2.23     Mindirra92
# 416   25    Male      84  Arcane Gem   2.23     Hiarideu73
# 440   21    Male      84  Arcane Gem   2.23  Stryanastip77
# 541   20    Male      84  Arcane Gem   2.23   Eosursurap97
# 711   22    Male      84  Arcane Gem   2.23  Tyananurgue44
# 742   26    Male      84  Arcane Gem   2.23      Inguron55
# 766   22  Female      84  Arcane Gem   2.23    Nitherian58

# %%
#**Most Profitable Items**
df2 = df.groupby('ItemName', sort=False).count() 
df2.sort_values(['Price'], ascending=False, inplace=True)
df2['ItemValue'] = df.groupby(['ItemName'])['Price'].sum() 
df2.head(5)
# Identify the 5 most profitable items by total purchase value, then list (in a table):
#  * Item ID
#  * Item Name
#  * Purchase Count
#  * Item Price
#  * Total Purchase Value
# Out:
#                                       Age  Gender  ItemID  Price  SN  \
# ItemName
# Final Critic                           14      14      14     14  14
# Arcane Gem                             11      11      11     11  11
# Betrayal, Whisper of Grieving Widows   11      11      11     11  11
# Stormcaller                            10      10      10     10  10
# Woeful Adamantite Claymore              9       9       9      9   9
#
#                                       ItemValue
# ItemName
# Final Critic                              38.60
# Arcane Gem                                24.53
# Betrayal, Whisper of Grieving Widows      25.85
# Stormcaller                               34.65
# Woeful Adamantite Claymore                11.16
